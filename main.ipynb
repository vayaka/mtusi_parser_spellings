# %%
import pandas as pd
import glob
import tabula

# %%
files_pdf = glob.glob(r'test_files/*.pdf')
files_pdf
# Out:
# ['test_files\\BIK2301.pdf',
#  'test_files\\BIN2301.pdf',
#  'test_files\\BIN2304.pdf',
#  'test_files\\BIN2305.pdf',
#  'test_files\\BIN2306.pdf']

# %%
pdf_tables = tabula.read_pdf(files_pdf[3],
                             pages='all',
                             multiple_tables=True,
                             lattice=True)

# %%
for table in pdf_tables:
    display(table)
# Out:
#     Unnamed: 0   Unnamed: 1  Unnamed: 2   Unnamed: 3  Unnamed: 4   Unnamed: 5  \
# 0          NaN  День недели         NaN         Пара         NaN        Время
# 1          NaN  понедельник         NaN            1         NaN  09.30-11.05
# 2          NaN          NaN         NaN            2         NaN  11.20-12.55
# 3          NaN          NaN         NaN            3         NaN  13.10-14.45
# 4          NaN          NaN         NaN            4         NaN  15.25-17.00
# 5          NaN          NaN         NaN            5         NaN  17.15-18.50
# 6          NaN      вторник         NaN            1         NaN  09.30-11.05
# 7          NaN          NaN         NaN            2         NaN  11.20-12.55
# 8          NaN          NaN         NaN            3         NaN  13.10-14.45
# 9          NaN          NaN         NaN            4         NaN  15.25-17.00
# 10         NaN          NaN         NaN            5         NaN  17.15-18.50
# ...

# %%
pdf_tables[0].loc["..."]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pdf_tables[0].loc["..."]
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\mtusi-parser-spellings-Z_ioWNCD-py3.10\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\mtusi-parser-spellings-Z_ioWNCD-py3.10\lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# ...
